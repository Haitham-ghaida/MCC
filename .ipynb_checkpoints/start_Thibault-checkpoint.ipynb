# %%
import premise as ps

# %%
import bw2io as bi
import bw2data as bd

# %%
bd.projects.set_current('MCC')

# %%
bi.bw2setup()
# Out:
# Biosphere database already present!!! No setup is needed

# %%
ei391cdir = "/home/haithamth/Documents/ecoinvent/ecoin_cuttoff_391/ecoinvent 3.9.1_cutoff_ecoSpold02/datasets"
data_base_name = "ecoinvent-3.9.1-cuttoff"
if data_base_name in bd.databases:
    print("Database has already been imported")
else:
    ei391c = bi.SingleOutputEcospold2Importer(ei391cdir, data_base_name)
    ei391c.apply_strategies()
    ei391c.statistics()

    #ei39.drop_unlinked(True)
    ei391c.write_database()
# Out:
# Database has already been imported

# %%
from premise import NewDatabase

# %%
# ndb = NewDatabase(
#     scenarios=[
#         {"model":"image", "pathway":"SSP2-RCP19", "year":2020},
#         {"model":"image", "pathway":"SSP2-RCP26", "year":2020},
#         {"model":"image", "pathway":"SSP2-RCP19", "year":2030},
#         {"model":"image", "pathway":"SSP2-RCP26", "year":2030},
#         {"model":"image", "pathway":"SSP2-RCP19", "year":2040},
#         {"model":"image", "pathway":"SSP2-RCP26", "year":2040},
#     ],
#     source_db="ecoinvent-3.9.1-cuttoff", # <-- name of the database in the BW2 project. Must be a string.
#     source_version="3.9.1", # <-- version of ecoinvent. Can be "3.5", "3.6", "3.7" or "3.8". Must be a string.
#     key='tUePmX_S5B8ieZkkM7WUU2CnO8SmShwmAeWK9x2rTFo=', # <-- decryption key
#     # to be requested from the library maintainers if you want ot use default scenarios included in `premise`
#     use_multiprocessing=True # <-- set to True if you want to use multiprocessing
# )

# %%
# ndb.update_electricity()

# %%
# ndb.write_db_to_brightway(["SSP2-RCP19_2020","SSP2-RCP26_2020", "SSP2-RCP19_2030","SSP2-RCP26_2030", "SSP2-RCP19_2040","SSP2-RCP26_2040"])

# %%
ecn = bd.Database("ecoinvent-3.9.1-cuttoff")

# %%
ecn.search('recycling')[0].key
# Out:
# ('ecoinvent-3.9.1-cuttoff', '92d2cd69b744fb751c6e0751c3a2b5a6')

# %%
import uuid
class Product:
    '''This class represents a product in the system, it should take care of the following:
    - Create a unique id for each product
    - Create a unique serial number for each product
    - Keep track of the product's service life
    '''
    # keep track of all instances of the class
    instances = []
    def __init__(self, name: str, amount: float, unit: str, service_life: int = None, production_lci: str = None, eol_lci: tuple[str,str] = None):
        # randomly generated id
        self.random_id = uuid.uuid4().hex
        self.name = name
        self.amount = amount
        self.unit = unit
        self.production_lci = production_lci
        self.service_life = service_life
        self.eol_lci = eol_lci
        self.embodied_impacts = {}
        self.instances.append(self) # keep track of all instances of the class

    # better representation of the class for humans
    def __repr__(self):
        return f"{self.name}"
    
    def replacement_sn(self):
        ...

# %%
import pandas as pd

# %%
building_data_construction = pd.read_excel(io = 'Case_study_existing_building_wEOL_4.xlsx', sheet_name = 'Construction', engine = 'openpyxl')

# %%
building_data_construction
# Out:
#     ID                 Building_component                   Main_material  \
# 0    1                         Foundation  concrete_foundation_production
# 1    2                         Foundation  concrete_foundation_production
# 2    3                         Foundation  concrete_foundation_production
# 3    4                         Foundation  concrete_foundation_production
# 4    5                     Superstructure  concrete_foundation_production
# 5    6                        Outer walls                        Concrete
# 6    7                        Outer walls              Insulation Mineral
# 7    8                        Outer walls                          Gypsum
# 8    9                        Outer walls                    Polyethylene
# 9   10                        Outer walls              Insulation Mineral
# 10  11                        Outer walls                        concrete
# 11  12                        Outer walls                           Glass
# 12  13                        Outer walls                            Wood
# 13  14                        Outer walls                         Mineral
# 14  15                        Outer walls                         Gypsium
# 15  16                        Outer walls                        concrete
# 16  17                        inner walls                        concrete
# 17  18                        inner walls                          Gypsum
# 18  19                        inner walls                        concrete
# 19  20                        inner walls                          Gypsum
# 20  21                        inner walls                           Glass
# 21  22                        inner walls                            Wood
# 22  23                        inner walls                           Glass
# 23  24                    Floor structure              Insulation Mineral
# 24  25                    Floor structure                        concrete
# 25  26                    Floor structure                    Polyethylene
# 26  27                    Floor structure                          Gypsum
# 27  28                         Outer roof                         Mineral
# 28  29                         Outer roof                        concrete
# 29  30                         Outer roof                   Insulation PS
# 30  31                         Outer roof                    Polyethylene
# 31  32                         Outer roof                          Gypsum
# 32  33                              Other                       Technical
# 33  34                              Other                       Technical
# 34  35                              Other                       Technical
# 35  36                              Other                       Technical
# 36  37  Ventilation and Air contitionning                       Technical
# 37  38                              Other                   Energy system
#
#                       Ecoinvent_activity_construction  \
# 0                      concrete_foundation_production
# 1      polystyrene foam slab production, 45% recycled
# 2     polyethylene production, low density, granulate
# 3                         fibreboard production, hard
# 4           steel production, low-alloyed, hot rolled
# 5   concrete production, 25MPa, for building const...
# 6                           glass wool mat production
# 7                      gypsum plasterboard production
# 8   polyethylene production, high density, granula...
# 9     polyethylene production, low density, granulate
# 10  concrete production, 25MPa, for building const...
# 11    window frame production, aluminium, U=1.6 W/m2K
# 12                 door production, outer, wood-glass
# 13            fibre cement corrugated slab production
# 14                                 market for plywood
# 15  concrete production, 25MPa, for building const...
# 16  concrete production, 25MPa, for building const...
# 17                     gypsum plasterboard production
# 18  concrete production, 25MPa, for building const...
# 19                     gypsum plasterboard production
# 20                      flat glass production, coated
# 21             door production, outer, wood-aluminium
# 22                            ceramic tile production
# 23                          glass wool mat production
# 24                           market for concrete slab
# 25    polyethylene production, low density, granulate
# 26                     gypsum plasterboard production
# 27                 fibre cement roof slate production
# 28                      concrete roof tile production
# 29                   polystyrene foam slab production
# 30    polyethylene production, low density, granulate
# 31                     gypsum plasterboard production
# 32   polyethylene production, high density, granulate
# 33           steel production, converter, low-alloyed
# 34                    hot water tank production, 600l
# 35                              gas boiler production
# 36      ventilation duct production, steel, 100x50 mm
# 37                evacuated tube collector production
#
#            Ecoinvent_key_construction    Amount Unit  Service_life  \
# 0    2eafb2856827730d501b1941671e3160     32.00   m3            78
# 1    2d1a6f71ee1b61ae0650e97319e5fad2    758.00   kg            78
# 2    872789ceaa2901313d31635a713c100e    158.00   kg            78
# 3    6032fcb0a208bdcdab5633d6be417d0e      2.00   m3            78
# 4    122c59aadb5e5ea3c902711215df0209    800.00   kg            80
# 5    a669e51fe80559ec5e2ab48228b7b87f  91072.00   kg            80
# 6    b319940a53dddcf86d6de0d37b88f8d6   2480.00   kg            38
# 7    0b4ac2320024c8b8cce38bd333b9817f   3524.00   kg            80
# 8    1580abc0d8542f9117775cc18e264f97    335.00   kg            80
# 9    872789ceaa2901313d31635a713c100e    231.00   kg            38
# 10   a669e51fe80559ec5e2ab48228b7b87f      1.95   m3            80
# 11   4cf9a902a18af16f767f74f63b705912     42.30   m2            30
# 12   ac417e7f2890b2eb87a7f685e275857e     41.70   m2            80
# 13   f7cba7c0fefc76cf37a65b48bc0da6dc    540.00   kg            80
# 14   ac17a3d6e017444c41eb5ff3be407877      1.80   m3            80
# 15   0b6c18fa9c1c179d47f8fab388a46f29   2765.00   kg            80
# 16   0b6c18fa9c1c179d47f8fab388a46f29    147.00   kg            40
# 17   0b4ac2320024c8b8cce38bd333b9817f    363.00   kg            40
# 18   0b6c18fa9c1c179d47f8fab388a46f29    578.00   kg            40
# 19   0b4ac2320024c8b8cce38bd333b9817f   2195.00   kg            40
# 20   6b0d0d8e979df0e13df8df4bb4a13937     63.00   kg            40
# 21   f01da346064ac8bf21ded7059c994b9a     12.60   m2            40
# 22   4c4f7ca9062f5f38fe7c02bd57ce2fbd   2315.00   kg            40
# 23   b319940a53dddcf86d6de0d37b88f8d6    750.00   kg            35
# 24   ff8c32b4d54c57ab67bf3cc01b13539f     85.20   m3            35
# 25   872789ceaa2901313d31635a713c100e    700.00   kg            35
# 26   0b4ac2320024c8b8cce38bd333b9817f    873.00   kg            35
# 27   bb55614763ad8438c61f5c6767cd2e1b    693.00   kg            35
# 28   308a29b5b6b681306a3fe2bef62c400a   7100.00   kg            35
# 29   2d1a6f71ee1b61ae0650e97319e5fad2    632.00   kg            35
# 30   872789ceaa2901313d31635a713c100e    159.00   kg            35
# 31   0b4ac2320024c8b8cce38bd333b9817f    962.00   kg            35
# 32   1580abc0d8542f9117775cc18e264f97     18.00   kg            26
# 33   89cb4e1a47b707fe43b99135b81fcaba     98.00   kg            26
# 34   1c2dd8677907f88a0746b958ca4efd43      1.00   pc            26
# 35   932f861aecca8621f12e22e5f8ccb775      1.00   pc            26
# 36   adc6bbccf3d5b2955b050510e647852a    196.00    m            26
# 37   6032fcb0a208bdcdab5633d6be417d0e      8.00   m2            26
#
#                                Ecoinvent_activity_eol  \
# 0   treatment of waste concrete, inert material la...
# 1   treatment of municipal solid waste, incinerati...
# 2   treatment of municipal solid waste, incinerati...
# 3   treatment of waste fibreboard, collection for ...
# 4   treatment of scrap steel, municipal incinerati...
# 5   treatment of waste concrete, inert material la...
# 6     treatment of waste mineral wool, recycling (CH)
# 7                             market for waste gypsum
# 8   treatment of municipal solid waste, incinerati...
# 9   treatment of municipal solid waste, incinerati...
# 10  treatment of waste concrete, inert material la...
# 11  treatment of waste glass, municipal incinerati...
# 12  treatment of waste fibreboard, collection for ...
# 13  treatment of municipal solid waste, incinerati...
# 14                            market for waste gypsum
# 15  treatment of waste concrete, inert material la...
# 16  treatment of waste concrete, inert material la...
# 17                            market for waste gypsum
# 18  treatment of waste concrete, inert material la...
# 19                            market for waste gypsum
# 20  treatment of waste glass, municipal incinerati...
# 21  treatment of waste fibreboard, collection for ...
# 22  treatment of waste glass, municipal incinerati...
# 23  treatment of municipal solid waste, incinerati...
# 24  treatment of waste concrete, inert material la...
# 25  treatment of municipal solid waste, incinerati...
# 26                            market for waste gypsum
# 27  treatment of waste concrete, inert material la...
# 28  treatment of waste concrete, inert material la...
# 29  treatment of waste expanded polystyrene, munic...
# 30  treatment of municipal solid waste, incinerati...
# 31                            market for waste gypsum
# 32  treatment of scrap steel, municipal incinerati...
# 33  treatment of scrap steel, municipal incinerati...
# 34  treatment of scrap steel, municipal incinerati...
# 35  treatment of scrap steel, municipal incinerati...
# 36  treatment of scrap steel, municipal incinerati...
# 37  treatment of scrap steel, municipal incinerati...
#
#                      Ecoinvent_key_eol
# 0    9526011b40bb76a51963028784dd315b'
# 1     5459b69c924e694863fe07b6beca9d31
# 2     5459b69c924e694863fe07b6beca9d31
# 3   '5f551cc90e19303fcbd5c24385c38544'
# 4    9fda2f5ef0c1309141b798483b169b23'
# 5    9526011b40bb76a51963028784dd315b'
# 6     dfbe1a3bd6a1238f0f31d3ccab50fd72
# 7   'a4691e46aed0e2930eb906b649d10e5d'
# 8     5459b69c924e694863fe07b6beca9d31
# 9     5459b69c924e694863fe07b6beca9d31
# 10   9526011b40bb76a51963028784dd315b'
# 11    4bc9d21071e8ba4901877ca4ab4ba175
# 12  '5f551cc90e19303fcbd5c24385c38544'
# 13    5459b69c924e694863fe07b6beca9d31
# 14  'a4691e46aed0e2930eb906b649d10e5d'
# 15   9526011b40bb76a51963028784dd315b'
# 16   9526011b40bb76a51963028784dd315b'
# 17  'a4691e46aed0e2930eb906b649d10e5d'
# 18   9526011b40bb76a51963028784dd315b'
# 19  'a4691e46aed0e2930eb906b649d10e5d'
# 20    6e42121fc70b20fd5cb6d57925f7e017
# 21  '5f551cc90e19303fcbd5c24385c38544'
# 22    6e42121fc70b20fd5cb6d57925f7e017
# 23    b319940a53dddcf86d6de0d37b88f8d6
# 24   9526011b40bb76a51963028784dd315b'
# 25    5459b69c924e694863fe07b6beca9d31
# 26  'a4691e46aed0e2930eb906b649d10e5d'
# 27   9526011b40bb76a51963028784dd315b'
# 28   9526011b40bb76a51963028784dd315b'
# 29    79673e39456fb26f4665f9ed807e9b3a
# 30    5459b69c924e694863fe07b6beca9d31
# 31  'a4691e46aed0e2930eb906b649d10e5d'
# 32   9fda2f5ef0c1309141b798483b169b23'
# 33   9fda2f5ef0c1309141b798483b169b23'
# 34   9fda2f5ef0c1309141b798483b169b23'
# 35   9fda2f5ef0c1309141b798483b169b23'
# 36   9fda2f5ef0c1309141b798483b169b23'
# 37   9fda2f5ef0c1309141b798483b169b23'

# %%
for index in building_data_construction.index :
    Product(name=building_data_construction['Ecoinvent_activity_construction'][index],
            amount = building_data_construction['Amount'][index],
            unit = building_data_construction['Unit'][index],
            service_life = building_data_construction['Service_life'][index],
            production_lci = building_data_construction['Ecoinvent_key_construction'][index],
            eol_lci = building_data_construction['Ecoinvent_key_eol'][index]
           )

# %%
Product.instances
# Out:
# [concrete_foundation_production,
#  polystyrene foam slab production, 45% recycled,
#  polyethylene production, low density, granulate,
#  fibreboard production, hard,
#  steel production, low-alloyed, hot rolled,
#  concrete production, 25MPa, for building construction, for interior use, with cement ZN/D, with 50% RC-C aggregates,
#  glass wool mat production,
#  gypsum plasterboard production,
#  polyethylene production, high density, granulate, recycled,
#  polyethylene production, low density, granulate,
#  concrete production, 25MPa, for building construction, for interior use, with cement ZN/D, with 50% RC-C aggregates,
#  window frame production, aluminium, U=1.6 W/m2K,
#  door production, outer, wood-glass,
#  fibre cement corrugated slab production,
#  market for plywood,
#  concrete production, 25MPa, for building construction, for interior use, with cement ZN/D, with 50% RC-C aggregates,
#  concrete production, 25MPa, for building construction, for interior use, with cement ZN/D, with 50% RC-C aggregates,
#  gypsum plasterboard production,
#  concrete production, 25MPa, for building construction, for interior use, with cement ZN/D, with 50% RC-C aggregates,
#  gypsum plasterboard production,
#  flat glass production, coated,
#  door production, outer, wood-aluminium,
#  ceramic tile production,
#  glass wool mat production,
#  market for concrete slab,
#  polyethylene production, low density, granulate,
#  gypsum plasterboard production,
#  fibre cement roof slate production,
#  concrete roof tile production,
#  polystyrene foam slab production,
#  polyethylene production, low density, granulate,
#  gypsum plasterboard production,
#  polyethylene production, high density, granulate,
#  steel production, converter, low-alloyed,
#  hot water tank production, 600l,
#  gas boiler production,
#  ventilation duct production, steel, 100x50 mm,
#  evacuated tube collector production]

# %%
p = Product(name='green', amount=1, unit='kg', service_life=20, production_lci= 'd872e0d78319cb13e12b96de83e19dd7',
            eol_lci= 'a5f2280b72eab45fac5be638870c61ae')

# %%
p2 = Product(name='rabbit', amount=2, unit='kg', service_life=16, production_lci='d872e0d78319cb13e12b96de83e19dd7',
             eol_lci= '92d2cd69b744fb751c6e0751c3a2b5a6')

# %%
class Mfa:
    '''
    This class represents a material flow analysis, it should take care of the following:
    - Create a time line for the analysis
    - Create a list of points in time where replacements occur
    '''
    def __init__(self, start: int = 2020, end: int = 2080, time_step: int = 10):
        self.start = start
        self.end = end
        self.time_step = time_step
        self.time_line = list(range(self.start, self.end+1, self.time_step)) # create a time line
        self.points = []
        self.embodied_impacts = {} # not currently used
        self.max_year = self.get_max_db_year()
        
    
    def add_points(self, product: Product):
        '''
        This function adds points to the time line where replacements occur'''
        first_repl = product.service_life + self.start
        
        for i in range(first_repl, self.end-1, product.service_life):
            self.points.append((i, product))
        # clean duplicates
        self.points = list(set(self.points))
        # sort by year
        self.points = sorted(self.points, key=lambda x: x[0])
        return self.points
    
    
    def create_time_line_dict(self):
        '''
        This function creates a dictionary of databases for each year in the time line'''
        # initialize a dictionary to store yearly databases
        yearly_databases = {}
        # iterate through all years in the time line
        for year in self.time_line:
            # initialize an empty list for each year
            yearly_databases[year] = []
        # iterate through all databases in the project
        for db in bd.databases:
            # split the database name by underscore ***IMPORTANT*** pay attention the the naming convention of the databases it has to be SPPX-RPCxx_YYYY
            db_processed = str(db).split("_")
            if db_processed[0] == 'ecoinvent-3.9.1-cuttoff':
                ecoinvent = db
            # if the database name has more than one element after splitting by underscore, then it is a scenario database
            elif len(db_processed) > 1:
                yearly_databases[int(db_processed[1])].append(db)
        return yearly_databases
    
    
    def get_max_db_year(self):
        '''This gives you the last(max) year in the dictionary where databases exist'''
        db_dict =  self.create_time_line_dict()
        for year in reversed(sorted(db_dict.keys())):
            if len(db_dict[year]) > 0:
                return year
            
    def clean_list_for_lca(self):
        '''this function provides the a list of tuples, the first value of the tuple is the year and the second value is the code of the activity'''
        # initialize an empty list
        clean_list = []
        for point in self.points:
            clean_list.append((point[0], point[1].production_lci))
            clean_list.append((point[0], point[1].eol_lci))
        return clean_list

# %%
tl = Mfa(start=2020, end=2050)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 tl = Mfa(start=2020, end=2050)
#
# Cell In[7], line 14, in Mfa.__init__(self, start, end, time_step)
#      12 self.points = []
#      13 self.embodied_impacts = {} # not currently used
# ---> 14 self.max_year = self.get_max_db_year()
#
# Cell In[7], line 54, in Mfa.get_max_db_year(self)
#      52 def get_max_db_year(self):
#      53     '''This gives you the last(max) year in the dictionary where databases exist'''
# ---> 54     db_dict =  self.create_time_line_dict()
#      55     for year in reversed(sorted(db_dict.keys())):
#      56         if len(db_dict[year]) > 0:
#
# Cell In[7], line 41, in Mfa.create_time_line_dict(self)
#      39     yearly_databases[year] = []
#      40 # iterate through all databases in the project
# ---> 41 for db in bd.databases:
#      42     # split the database name by underscore ***IMPORTANT*** pay attention the the naming convention of the databases it has to be SPPX-RPCxx_YYYY
#      43     db_processed = str(db).split("_")
#      44     if db_processed[0] == 'ecoinvent-3.9.1-cuttoff':
#
# NameError: name 'bd' is not defined

# %%
tl.add_points(p)
tl.add_points(p2)
# Out:
# [(2036, rabbit), (2040, green)]

# %%
tl.clean_list_for_lca()
# Out:
# [(2036, 'd872e0d78319cb13e12b96de83e19dd7'),
#  (2036, '92d2cd69b744fb751c6e0751c3a2b5a6'),
#  (2040, 'd872e0d78319cb13e12b96de83e19dd7'),
#  (2040, 'a5f2280b72eab45fac5be638870c61ae')]

# %%
# import bw2calc as bc
# class ProLCA:
#     '''
#     This class should take care of the following:
#     - Create a production lca for each product
#     - Create a time line based lca for each product
#     - Create a future lca for each product
#     - Create a future lca for the whole system
#     '''
#     def __init__(self, products: list[Product], mfa: Mfa, methods: list[tuple[str,str,str]] = [('EF v3.0 EN15804', 'climate change', 'global warming potential (GWP100)')]):
#         self.products = products
#         self.mfa = mfa
#         self.methods = methods
#         self.yearly_databases = mfa.create_time_line_dict()
    
    
#     def database_chooser(self, year):
#         '''
#         This function chooses the appropriate database(s) based on the year'''
#         available_years = self.yearly_databases.keys()
#         # make sure that the function that create_time_line_dict is called before this function and a dictionary of yearly databases is created
#         assert len(available_years) > 0, "Please create a dictionary of yearly databases first"
#         # check if the year is in the available years
#         if year in available_years:
#             # just return the database for that year
#             return self.yearly_databases[year]
#         # if the year is not in the available years, then check if it is less than the minimum year
#         elif year < min(available_years):
#             return self.yearly_databases[min(available_years)]
#         # if the year is not in the available years, then check if it is greater than the maximum year
#         elif year > max(available_years):
#             return self.yearly_databases[max(available_years)]
#         else:
#             # round down to the nearest year
#             return self.yearly_databases[year - (year % 10)]
        
    
#     def time_line_based_renovation_lca(self):
#         '''
#         This function calculates the production lca for each product in the time line
#         it mainly takes care of the impacts of the products needed for renovation'''
#         results_dict = {}
#         for point in self.mfa.points:
#             for product in self.products:
#                 # Check if the second element in `point` equals `product`
#                 if point[1] == product:
#                     # Choose the appropriate database(s) based on the year
#                     dbs = self.database_chooser(year=point[0])
                    
#                     # Iterate through all chosen databases
#                     for db in dbs:
#                         # Construct a unique key for storing results
#                         result_key = f"{point[0]}_{product}_{db}"
#                         # Ensure fetched_db returns the expected database
#                         fetched_db = bd.Database(str(db))
                        
#                         # Ensure this returns the expected activity
#                         activity = fetched_db.get(product.production_lci[1])
                        
#                         # Define the functional unit for the LCA
#                         amount = product.amount
#                         fu = {activity: amount}
                        
#                         # Initialize the LCA with the first method and calculate impacts
#                         lca = bc.LCA(fu, self.methods[0])
#                         lca.lci()
#                         lca.lcia()
                        
#                         # Initialize a list to store impact scores for all methods
#                         impacts = [lca.score]
                        
#                         # If there are additional methods, switch methods and calculate additional impacts
#                         if len(self.methods) > 1:    
#                             for method in self.methods[1:]:
#                                 lca.switch_method(method)
#                                 lca.lcia()
#                                 impacts.append(lca.score)
                        
#                         # Store all calculated impacts in the results dictionary
#                         results_dict[result_key] = impacts
#         return results_dict
    
#     def time_line_based_eol_renovation_lca(self):
#         '''
#         This function calculates the eol lca for each product in the time line, basically the
#         same as the time_line_based_renovation_lca function but with different lci activity
#         it takes care of the eol of products that are replaced or renovated'''
#         results_dict = {}
#         for point in self.mfa.points:
#             for product in self.products:
#                 # Check if the second element in `point` equals `product`
#                 if point[1] == product:
#                     # Choose the appropriate database(s) based on the year
#                     dbs = self.database_chooser(year=point[0])
                    
#                     # Iterate through all chosen databases
#                     for db in dbs:
#                         # Construct a unique key for storing results
#                         result_key = f"{point[0]}_{product}_{db}"
#                         # Ensure fetched_db returns the expected database
#                         fetched_db = bd.Database(str(db))
                        
#                         # Ensure this returns the expected activity
#                         activity = fetched_db.get(product.eol_lci[1])
                        
#                         # Define the functional unit for the LCA
#                         amount = product.amount
#                         fu = {activity: amount}
                        
#                         # Initialize the LCA with the first method and calculate impacts
#                         lca = bc.LCA(fu, self.methods[0])
#                         lca.lci()
#                         lca.lcia()
                        
#                         # Initialize a list to store impact scores for all methods
#                         impacts = [lca.score]
                        
#                         # If there are additional methods, switch methods and calculate additional impacts
#                         if len(self.methods) > 1:    
#                             for method in self.methods[1:]:
#                                 lca.switch_method(method)
#                                 lca.lcia()
#                                 impacts.append(lca.score)
                        
#                         # Store all calculated impacts in the results dictionary
#                         results_dict[result_key] = impacts
#         return results_dict
    
#     def production_lca(self, db = 'ecoinvent-3.9.1-cuttoff'):
#         results_dict = {}
#         for product in self.products:            
#             # Construct a unique key for storing results
#             result_key = f"{self.mfa.start}_{product}_{db}"
            
#             fetched_db = bd.Database(str(db))
#             # Ensure this returns the expected activity
#             activity = fetched_db.get(product.production_lci[1])
            
#             # Define the functional unit for the LCA
#             amount = product.amount
#             fu = {activity: amount}
            
#             # Initialize the LCA with the first method and calculate impacts
#             lca = bc.LCA(fu, self.methods[0])
#             lca.lci()
#             lca.lcia()
            
#             # Initialize a list to store impact scores for all methods
#             impacts = [lca.score]
            
#             # If there are additional methods, switch methods and calculate additional impacts
#             if len(self.methods) > 1:    
#                 for method in self.methods[1:]:
#                     lca.switch_method(method)
#                     lca.lcia()
#                     impacts.append(lca.score)
            
#             # Store all calculated impacts in the results dictionary
#             results_dict[result_key] = impacts
#         return results_dict
    
#     def eol_lca(self):
#         results_dict = {}
#         max_db_year = self.mfa.get_max_db_year()
#         dbs = self.database_chooser(max_db_year)
#         for product in self.products:
#             for db in dbs:
#                 # Construct a unique key for storing results
#                 result_key = f"{self.mfa.end}_{product}_{db}"
                
#                 fetched_db = bd.Database(str(db))
#                 # Ensure this returns the expected activity
#                 activity = fetched_db.get(product.production_lci[1])
                
#                 # Define the functional unit for the LCA
#                 amount = product.amount
#                 fu = {activity: amount}
                
#                 # Initialize the LCA with the first method and calculate impacts
#                 lca = bc.LCA(fu, self.methods[0])
#                 lca.lci()
#                 lca.lcia()
                
#                 # Initialize a list to store impact scores for all methods
#                 impacts = [lca.score]
                
#                 # If there are additional methods, switch methods and calculate additional impacts
#                 if len(self.methods) > 1:    
#                     for method in self.methods[1:]:
#                         lca.switch_method(method)
#                         lca.lcia()
#                         impacts.append(lca.score)
                
#                 # Store all calculated impacts in the results dictionary
#                 results_dict[result_key] = impacts
#         return results_dict
    
#     def heating_electricity_lca(self):
#         pass

# %%
import bw2calc as bc
class ProLCA:
    '''
    This class should take care of the following:
    - Create a production lca for each product
    - Create a time line based lca for each product
    - Create a future lca for each product
    - Create a future lca for the whole system
    '''
    def __init__(self, activities_and_years: list[tuple[str, int]],
                 methods: list[tuple[str,str,str]] = [('EF v3.0 EN15804', 'climate change', 'global warming potential (GWP100)'),], yearly_databases: dict = None):
        self.activities_and_years = activities_and_years
        self.methods = methods
        self.yearly_databases = yearly_databases
        self.results = {}
        self.results_aggregated = {}

    def production_lca(self, db = 'ecoinvent-3.9.1-cuttoff'):
         results_dict = {}
         for product in self.products:            
             # Construct a unique key for storing results
             result_key = f"{self.mfa.start}_{product}_{db}"
           
             fetched_db = bd.Database(str(db))
             # Ensure this returns the expected activity
             activity = fetched_db.get(product.production_lci[1])
           
             # Define the functional unit for the LCA
             amount = product.amount
             fu = {activity: amount}
           
             # Initialize the LCA with the first method and calculate impacts
             lca = bc.LCA(fu, self.methods[0])
             lca.lci()
             lca.lcia()
           
             # Initialize a list to store impact scores for all methods
             impacts = [lca.score]
           
             # If there are additional methods, switch methods and calculate additional impacts
             if len(self.methods) > 1:    
                 for method in self.methods[1:]:
                     lca.switch_method(method)
                     lca.lcia()
                     impacts.append(lca.score)
           
             # Store all calculated impacts in the results dictionary
             results_dict[result_key] = impacts
         return results_dict
        
    
    def eol_lca(self):
         results_dict = {}
         max_db_year = self.mfa.get_max_db_year()
         dbs = self.database_chooser(max_db_year)
         for product in self.products:
             for db in dbs:
                 # Construct a unique key for storing results
                 result_key = f"{self.mfa.end}_{product}_{db}"
               
                 fetched_db = bd.Database(str(db))
                 # Ensure this returns the expected activity
                 activity = fetched_db.get(product.production_lci[1])
               
                 # Define the functional unit for the LCA
                 amount = product.amount
                 fu = {activity: amount}
               
                 # Initialize the LCA with the first method and calculate impacts
                 lca = bc.LCA(fu, self.methods[0])
                 lca.lci()
                 lca.lcia()
               
                 # Initialize a list to store impact scores for all methods
                 impacts = [lca.score]
               
                 # If there are additional methods, switch methods and calculate additional impacts
                 if len(self.methods) > 1:    
                     for method in self.methods[1:]:
                         lca.switch_method(method)
                         lca.lcia()
                         impacts.append(lca.score)
               
                 # Store all calculated impacts in the results dictionary
                 results_dict[result_key] = impacts
         return results_dict
   

    
    def database_chooser(self, year):
        '''
        This function chooses the appropriate database(s) based on the year'''
        available_years = self.yearly_databases.keys()
        # make sure that the function that create_time_line_dict is called before this function and a dictionary of yearly databases is created
        assert len(available_years) > 0, "Please create a dictionary of yearly databases first"
        # check if the year is in the available years
        if year in available_years:
            # just return the database for that year
            return self.yearly_databases[year]
        # if the year is not in the available years, then check if it is less than the minimum year
        elif year < min(available_years):
            return self.yearly_databases[min(available_years)]
        # if the year is not in the available years, then check if it is greater than the maximum year
        elif year > max(available_years):
            return self.yearly_databases[max(available_years)]
        else:
            # round down to the nearest year
            return self.yearly_databases[year - (year % 10)]

    def give_me_embodied(self):
        '''give me the lca please'''
        # initialize an empty dictionary to store results
        results_dict = {}
        # 
        
        # iterate through all years in the time line
        for year, activity in self.activities_and_years:            
            # Choose the appropriate database(s) based on the year
            dbs = self.database_chooser(year)
            # Iterate through all chosen databases
            for db in dbs:
                # check if year and activity are already in the results dictionary if so, skip
                if (year, activity, db) in results_dict.keys():
                    continue
                # Construct a unique key for storing results
                result_key = (year, activity, db)
                # get the activity from the database
                demand = bd.get_activity((str(db), activity))
                # Define the functional unit for the LCA
                amount = 1
                fu = {demand: amount}
                # Initialize the LCA with the first method and calculate impacts
                lca = bc.LCA(fu, self.methods[0])
                lca.lci()
                lca.lcia()
                impacts = [lca.score]
                # If there are additional methods, switch methods and calculate additional impacts
                if len(self.methods) > 1:    
                    for method in self.methods[1:]:
                        lca.switch_method(method)
                        lca.lcia()
                        impacts.append(lca.score)

                # Store all calculated impacts in the results dictionary
                results_dict[result_key] = impacts
        return results_dict

    def give_me_embodied_construction(self):
        '''give me the lca please of the construction adn EoL phases'''
        # initialize an empty dictionary to store results
        results_dict = {}
        db = "ecoinvent-3.9.1-cuttoff" # construction phase occurs in 2020 (start year) with the ecoinvent database
        year = self.start
        # iterate through the activities to take into account the construction phase
        for activity in self.instances :
            # Construct a unique key for storing results
            result_key = (year, activity, db)
            # get the activity from the database
            demand = bd.get_activity((str(db), activity))
            # Define the functional unit for the LCA
            amount = 1
            fu = {demand: amount}
            # Initialize the LCA with the first method and calculate impacts
            lca = bc.LCA(fu, self.methods[0])
            lca.lci()
            lca.lcia()
            impacts = [lca.score]
            # If there are additional methods, switch methods and calculate additional impacts
            if len(self.methods) > 1:    
                for method in self.methods[1:]:
                    lca.switch_method(method)
                    lca.lcia()
                    impacts.append(lca.score)

            # Store all calculated impacts in the results dictionary
            results_dict[result_key] = impacts
        return results_dict

# %%
lca2 = ProLCA(activities_and_years=tl.clean_list_for_lca(), yearly_databases=tl.create_time_line_dict(), methods=[('EF v3.0 EN15804', 'climate change', 'global warming potential (GWP100)'), ('EF v3.0 EN15804', 'acidification', 'accumulated exceedance (AE)')])

# %%
results = lca2.give_me_embodied()

# %%
results
# Out:
# {(2036,
#   'd872e0d78319cb13e12b96de83e19dd7',
#   'SSP2-RCP19_2030'): [1.704690182464366, 0.0061609604473516445],
#  (2036,
#   'd872e0d78319cb13e12b96de83e19dd7',
#   'SSP2-RCP26_2030'): [1.8391922681749882, 0.006631959383662307],
#  (2036,
#   '92d2cd69b744fb751c6e0751c3a2b5a6',
#   'SSP2-RCP19_2030'): [0.15624137970034158, 0.0005927216833403848],
#  (2036,
#   '92d2cd69b744fb751c6e0751c3a2b5a6',
#   'SSP2-RCP26_2030'): [0.17491520470736674, 0.0006474137351223672],
#  (2040,
#   'd872e0d78319cb13e12b96de83e19dd7',
#   'SSP2-RCP19_2040'): [1.664174817198441, 0.005990449802518106],
#  (2040,
#   'd872e0d78319cb13e12b96de83e19dd7',
#   'SSP2-RCP26_2040'): [1.7739710922834737, 0.006256772480144479],
#  (2040,
#   'a5f2280b72eab45fac5be638870c61ae',
#   'SSP2-RCP19_2040'): [-0.061773535038168695, -0.000566683393259233],
#  (2040,
#   'a5f2280b72eab45fac5be638870c61ae',
#   'SSP2-RCP26_2040'): [-0.0625605206879309, -0.0005684990797994778]}

# %%
import pandas as pd
class GiveMeName:
    
    '''
    an abstract class that takes care of the following:
    - writing the results to excel
    -aggregating the results
    - TO BE DONE: aggregating the results based on the time line'''
    
    def aggregator(lcia_dict, product) -> dict:
        # find all the keys in the lcia dictionary that contain the product code
        keys = [key for key in lcia_dict.keys() if product.production_lci in key or product.eol_lci in key]
        print(keys)

        # Create a new dictionary that contains only the relevant keys
        aggregated_lcia = {key: [x * product.amount for x in lcia_dict[key]] for key in keys}
        
        return aggregated_lcia
    
    def bd_get_activity(db_code) -> str:
        # Your existing bd.get_activity logic
        return bd.get_activity(db_code)['name']
    
    import pandas as pd

    def poop_to_excel(data, bd_get_activity, output_file='output.xlsx') -> None:
        """
        Generate an Excel file containing impacts data for each product.
        
        Parameters:
            data (dict): Dictionary containing products and their respective embodied impacts data.
            bd_get_activity (function): Function to retrieve activity name based on its code.
            output_file (str): Name of the output Excel file.
            
        Returns:
            None. Writes an Excel file to the specified output path.
        """
        # Accumulating unique activity codes to reduce API/database calls
        activity_codes = set([key[1] for product_data in data.values() for key in product_data.keys()])
        activity_names = {code: bd_get_activity(('SSP2-RCP19_2030', code)) for code in activity_codes}
        dfs = {}

        # Looping through each product and its associated embodied impacts
        for product_name, impacts_data in data.items():
            for (year, activity_code, database), impacts in impacts_data.items():
                for impact_idx, impact in enumerate(impacts):
                    if impact_idx not in dfs:
                        dfs[impact_idx] = []

                    dfs[impact_idx].append({
                        'Year': year,
                        'Database': database,
                        'Activity': activity_names[activity_code],
                        'Product': product_name,
                        'Impact': impact
                    })

        # Convert data to multi-indexed DataFrames
        dfs = {key: pd.DataFrame(value).set_index(['Year', 'Database', 'Activity', 'Product']) for key, value in dfs.items()}

        for key, df in dfs.items():
            # Sort by Year in other words combine all databases for each year
            dfs[key] = df.sort_index(level='Year')

        # Exporting the data to Excel
        with pd.ExcelWriter(output_file, engine='xlsxwriter') as writer:
            for sheet, df in dfs.items():
                df.to_excel(writer, sheet_name=f'Impact_{sheet}')

# %%
data = {}
for product in Product.instances:
    product.embodied_impacts = GiveMeName.aggregator(results, product)
    data[product.name] = product.embodied_impacts
# Out:
# [(2036, 'd872e0d78319cb13e12b96de83e19dd7', 'SSP2-RCP19_2030'), (2036, 'd872e0d78319cb13e12b96de83e19dd7', 'SSP2-RCP26_2030'), (2040, 'd872e0d78319cb13e12b96de83e19dd7', 'SSP2-RCP19_2040'), (2040, 'd872e0d78319cb13e12b96de83e19dd7', 'SSP2-RCP26_2040'), (2040, 'a5f2280b72eab45fac5be638870c61ae', 'SSP2-RCP19_2040'), (2040, 'a5f2280b72eab45fac5be638870c61ae', 'SSP2-RCP26_2040')]
# [(2036, 'd872e0d78319cb13e12b96de83e19dd7', 'SSP2-RCP19_2030'), (2036, 'd872e0d78319cb13e12b96de83e19dd7', 'SSP2-RCP26_2030'), (2036, '92d2cd69b744fb751c6e0751c3a2b5a6', 'SSP2-RCP19_2030'), (2036, '92d2cd69b744fb751c6e0751c3a2b5a6', 'SSP2-RCP26_2030'), (2040, 'd872e0d78319cb13e12b96de83e19dd7', 'SSP2-RCP19_2040'), (2040, 'd872e0d78319cb13e12b96de83e19dd7', 'SSP2-RCP26_2040')]

# %%
tl.points
# Out:
# [(2036, rabbit), (2040, green)]

# %%
results.keys()
[key for key in results.keys() if p.production_lci in key or p.eol_lci in key]
# Out:
# [(2036, 'd872e0d78319cb13e12b96de83e19dd7', 'SSP2-RCP19_2030'),
#  (2036, 'd872e0d78319cb13e12b96de83e19dd7', 'SSP2-RCP26_2030'),
#  (2040, 'd872e0d78319cb13e12b96de83e19dd7', 'SSP2-RCP19_2040'),
#  (2040, 'd872e0d78319cb13e12b96de83e19dd7', 'SSP2-RCP26_2040'),
#  (2040, 'a5f2280b72eab45fac5be638870c61ae', 'SSP2-RCP19_2040'),
#  (2040, 'a5f2280b72eab45fac5be638870c61ae', 'SSP2-RCP26_2040')]

# %%
GiveMeName.aggregator(results, p)
# Out:
# [(2036, 'd872e0d78319cb13e12b96de83e19dd7', 'SSP2-RCP19_2030'), (2036, 'd872e0d78319cb13e12b96de83e19dd7', 'SSP2-RCP26_2030'), (2040, 'd872e0d78319cb13e12b96de83e19dd7', 'SSP2-RCP19_2040'), (2040, 'd872e0d78319cb13e12b96de83e19dd7', 'SSP2-RCP26_2040'), (2040, 'a5f2280b72eab45fac5be638870c61ae', 'SSP2-RCP19_2040'), (2040, 'a5f2280b72eab45fac5be638870c61ae', 'SSP2-RCP26_2040')]
# {(2036,
#   'd872e0d78319cb13e12b96de83e19dd7',
#   'SSP2-RCP19_2030'): [1.704690182464366, 0.0061609604473516445],
#  (2036,
#   'd872e0d78319cb13e12b96de83e19dd7',
#   'SSP2-RCP26_2030'): [1.8391922681749882, 0.006631959383662307],
#  (2040,
#   'd872e0d78319cb13e12b96de83e19dd7',
#   'SSP2-RCP19_2040'): [1.664174817198441, 0.005990449802518106],
#  (2040,
#   'd872e0d78319cb13e12b96de83e19dd7',
#   'SSP2-RCP26_2040'): [1.7739710922834737, 0.006256772480144479],
#  (2040,
#   'a5f2280b72eab45fac5be638870c61ae',
#   'SSP2-RCP19_2040'): [-0.061773535038168695, -0.000566683393259233],
#  (2040,
#   'a5f2280b72eab45fac5be638870c61ae',
#   'SSP2-RCP26_2040'): [-0.0625605206879309, -0.0005684990797994778]}

# %%
data
# Out:
# {'green': {(2036,
#    'd872e0d78319cb13e12b96de83e19dd7',
#    'SSP2-RCP19_2030'): [1.704690182464366, 0.0061609604473516445],
#   (2036,
#    'd872e0d78319cb13e12b96de83e19dd7',
#    'SSP2-RCP26_2030'): [1.8391922681749882, 0.006631959383662307],
#   (2040,
#    'd872e0d78319cb13e12b96de83e19dd7',
#    'SSP2-RCP19_2040'): [1.664174817198441, 0.005990449802518106],
#   (2040,
#    'd872e0d78319cb13e12b96de83e19dd7',
#    'SSP2-RCP26_2040'): [1.7739710922834737, 0.006256772480144479],
#   (2040,
#    'a5f2280b72eab45fac5be638870c61ae',
#    'SSP2-RCP19_2040'): [-0.061773535038168695, -0.000566683393259233],
#   (2040,
#    'a5f2280b72eab45fac5be638870c61ae',
#    'SSP2-RCP26_2040'): [-0.0625605206879309, -0.0005684990797994778]},
#  'rabbit': {(2036,
#    'd872e0d78319cb13e12b96de83e19dd7',
#    'SSP2-RCP19_2030'): [3.409380364928732, 0.012321920894703289],
#   (2036,
#    'd872e0d78319cb13e12b96de83e19dd7',
#    'SSP2-RCP26_2030'): [3.6783845363499763, 0.013263918767324615],
#   (2036,
#    '92d2cd69b744fb751c6e0751c3a2b5a6',
#    'SSP2-RCP19_2030'): [0.31248275940068315, 0.0011854433666807695],
#   (2036,
#    '92d2cd69b744fb751c6e0751c3a2b5a6',
#    'SSP2-RCP26_2030'): [0.3498304094147335, 0.0012948274702447343],
#   (2040,
#    'd872e0d78319cb13e12b96de83e19dd7',
#    'SSP2-RCP19_2040'): [3.328349634396882, 0.011980899605036212],
#   (2040,
#    'd872e0d78319cb13e12b96de83e19dd7',
#    'SSP2-RCP26_2040'): [3.5479421845669474, 0.012513544960288957]}}

# %%
GiveMeName.poop_to_excel(data, GiveMeName.bd_get_activity, output_file='output.xlsx')

# %%
# p = Product(name='green', amount=1, unit='kg', service_life=20, production_lci= 'd872e0d78319cb13e12b96de83e19dd7',
#             eol_lci= 'a5f2280b72eab45fac5be638870c61ae')

# %%
# p2 = Product(name='rabbit', amount=2, unit='kg', service_life=16, production_lci='d872e0d78319cb13e12b96de83e19dd7',
#              eol_lci= '92d2cd69b744fb751c6e0751c3a2b5a6')

# %%
def aggregator_for_product_year(lcia_dict, year, product):
    # filter the keys in the lcia dictionary for the given year that match the product's production_lci or eol_lci
    keys = [key for key in lcia_dict.keys() if key[0] == year and (product.production_lci in key or product.eol_lci in key)]
    print(keys)
    # Create a new dictionary containing only the relevant keys
    aggregated_lcia = {key: [x * product.amount for x in lcia_dict[key]] for key in keys}
    return aggregated_lcia

def aggregate_timeline(lcia_dict, timeline_points):
    results = {}
    for year, product_name in timeline_points:
        # Here, you should retrieve the product object using the product_name from a database or another structure
        product = get_product_by_name(product_name)  
        results[year] = aggregator_for_product_year(lcia_dict, year, product)
    return results

# This is just a dummy function. You should replace this with your own function to get the product by name.
def get_product_by_name(product_name):
    # Replace this with your actual method of retrieving the product by name
    products = {
        'green': p,
        'rabbit': p2
    }
    return products[product_name]

timeline_points = [(2036, 'rabbit'), (2040, 'green')]
print(aggregate_timeline(results, timeline_points))
# Out:
# [(2036, 'd872e0d78319cb13e12b96de83e19dd7', 'SSP2-RCP19_2030'), (2036, 'd872e0d78319cb13e12b96de83e19dd7', 'SSP2-RCP26_2030'), (2036, '92d2cd69b744fb751c6e0751c3a2b5a6', 'SSP2-RCP19_2030'), (2036, '92d2cd69b744fb751c6e0751c3a2b5a6', 'SSP2-RCP26_2030')]
# [(2040, 'd872e0d78319cb13e12b96de83e19dd7', 'SSP2-RCP19_2040'), (2040, 'd872e0d78319cb13e12b96de83e19dd7', 'SSP2-RCP26_2040'), (2040, 'a5f2280b72eab45fac5be638870c61ae', 'SSP2-RCP19_2040'), (2040, 'a5f2280b72eab45fac5be638870c61ae', 'SSP2-RCP26_2040')]
# {2036: {(2036, 'd872e0d78319cb13e12b96de83e19dd7', 'SSP2-RCP19_2030'): [3.409380364928732, 0.012321920894703289], (2036, 'd872e0d78319cb13e12b96de83e19dd7', 'SSP2-RCP26_2030'): [3.6783845363499763, 0.013263918767324615], (2036, '92d2cd69b744fb751c6e0751c3a2b5a6', 'SSP2-RCP19_2030'): [0.31248275940068315, 0.0011854433666807695], (2036, '92d2cd69b744fb751c6e0751c3a2b5a6', 'SSP2-RCP26_2030'): [0.3498304094147335, 0.0012948274702447343]}, 2040: {(2040, 'd872e0d78319cb13e12b96de83e19dd7', 'SSP2-RCP19_2040'): [1.664174817198441, 0.005990449802518106], (2040, 'd872e0d78319cb13e12b96de83e19dd7', 'SSP2-RCP26_2040'): [1.7739710922834737, 0.006256772480144479], (2040, 'a5f2280b72eab45fac5be638870c61ae', 'SSP2-RCP19_2040'): [-0.061773535038168695, -0.000566683393259233], (2040, 'a5f2280b72eab45fac5be638870c61ae', 'SSP2-RCP26_2040'): [-0.0625605206879309, -0.0005684990797994778]}}
